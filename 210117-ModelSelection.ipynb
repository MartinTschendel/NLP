# %% [markdown]
# Check the performance of different classifiers by applying the following metrics:
# * Confusion Matrix
# * Accuracy (how many of the predicted results are similar to the test set results?
# * Precision (measuring exactness; when it predicts yes, how often is it correct?)
# * Recall (measuring completeness; when it's actually yes, how often does it predict yes?)
# * F1 Score (compromise between Precision and Recall）
# * Save the results within a dataframe and export it to a csv

# %%
import numpy as np
import pandas as pd
import re 
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

dataset = pd.read_csv('Restaurant_Reviews.tsv', delimiter='\t', quoting = 3)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in range(0, 1000):
    review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
    review = ' '.join(review) 
    corpus.append(review)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

def model_performance(y_pred):
    value_list = []
    cm = confusion_matrix(y_test, y_pred)
    TN = cm[0][0]
    value_list.append(cm[0][0])
    TP = cm[1][1]
    value_list.append(cm[1][1])
    FP = cm[0][1]
    value_list.append(cm[0][1])
    FN = cm[1][0]
    value_list.append(cm[1][0])
    Accuracy = (TP + TN) / (TP + TN + FP + FN)
    value_list.append(Accuracy)
    Precision = TP / (TP + FP)
    value_list.append(round(Precision, 3))
    Recall = TP / (TP + FN)
    value_list.append(round(Recall, 3))
    F1 = 2 * Precision * Recall / (Precision + Recall)
    value_list.append(round(F1, 3))
    return print((cm),'\n'
    'True Negatives:', cm[0][0],'\n'
    'True Positives:', cm[1][1],'\n'
    'False Positives:', cm[0][1],'\n'
    'False Negatives:', cm[1][0],'\n'
    'Accurary:', Accuracy,'\n'
    'Precision:', round(Precision, 3),'\n'
    'Recall:', round(Recall, 3),'\n'
    'F1 Score:', round(F1, 3)), value_list

# %%
list_nb = model_performance(y_pred)[1]
list_nb
# Out:
# [[55 42]
#  [12 91]]
# True Negatives: 55
# True Positives: 91
# False Positives: 42
# False Negatives: 12
# Accurary: 0.73
# Precision: 0.684
# Recall: 0.883
# F1 Score: 0.771
# [55, 91, 42, 12, 0.73, 0.684, 0.883, 0.771]

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
class_rf = RandomForestClassifier(n_estimators = 30, criterion = 'entropy', random_state = 0)
class_rf.fit(X_train, y_train)
y_pred = class_rf.predict(X_test)
list_rf = model_performance(y_pred)[1]
list_rf
# Out:
# [[87 10]
#  [45 58]]
# True Negatives: 87
# True Positives: 58
# False Positives: 10
# False Negatives: 45
# Accurary: 0.725
# Precision: 0.853
# Recall: 0.563
# F1 Score: 0.678
# [87, 58, 10, 45, 0.725, 0.853, 0.563, 0.678]

# %%
#Support Vector Machine Classifier
from sklearn.svm import SVC
class_svm = SVC(kernel = 'linear', random_state = 0)
class_svm.fit(X_train, y_train)
y_pred = class_svm.predict(X_test)
list_svm = model_performance(y_pred)[1]
list_svm
# Out:
# [[79 18]
#  [24 79]]
# True Negatives: 79
# True Positives: 79
# False Positives: 18
# False Negatives: 24
# Accurary: 0.79
# Precision: 0.814
# Recall: 0.767
# F1 Score: 0.79
# [79, 79, 18, 24, 0.79, 0.814, 0.767, 0.79]

# %%
#Kernel SVM Classifier
class_kern = SVC(kernel = 'rbf', random_state = 0)
class_kern.fit(X_train, y_train)
y_pred = class_kern.predict(X_test)
list_kern = model_performance(y_pred)[1]
list_kern
# Out:
# [[89  8]
#  [36 67]]
# True Negatives: 89
# True Positives: 67
# False Positives: 8
# False Negatives: 36
# Accurary: 0.78
# Precision: 0.893
# Recall: 0.65
# F1 Score: 0.753
# [89, 67, 8, 36, 0.78, 0.893, 0.65, 0.753]

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
class_tree = DecisionTreeClassifier(criterion = 'entropy', random_state=0)
class_tree.fit(X_train, y_train)
y_pred = class_tree.predict(X_test)
list_tree = model_performance(y_pred)[1]
list_tree
# Out:
# [[78 19]
#  [31 72]]
# True Negatives: 78
# True Positives: 72
# False Positives: 19
# False Negatives: 31
# Accurary: 0.75
# Precision: 0.791
# Recall: 0.699
# F1 Score: 0.742
# [78, 72, 19, 31, 0.75, 0.791, 0.699, 0.742]

# %%
from sklearn.neighbors import KNeighborsClassifier
class_knn = KNeighborsClassifier(n_neighbors = 10, metric = 'minkowski', p = 2)
class_knn.fit(X_train, y_train)
y_pred = class_knn.predict(X_test)
list_knn = model_performance(y_pred)[1]
list_knn
# Out:
# [[79 18]
#  [52 51]]
# True Negatives: 79
# True Positives: 51
# False Positives: 18
# False Negatives: 52
# Accurary: 0.65
# Precision: 0.739
# Recall: 0.495
# F1 Score: 0.593
# [79, 51, 18, 52, 0.65, 0.739, 0.495, 0.593]

# %%
from sklearn.linear_model import LogisticRegression
class_log = LogisticRegression(random_state = 0)
class_log.fit(X_train, y_train)
y_pred = class_log.predict(X_test)
list_log = model_performance(y_pred)[1]
list_log
# Out:
# [[80 17]
#  [28 75]]
# True Negatives: 80
# True Positives: 75
# False Positives: 17
# False Negatives: 28
# Accurary: 0.775
# Precision: 0.815
# Recall: 0.728
# F1 Score: 0.769
# [80, 75, 17, 28, 0.775, 0.815, 0.728, 0.769]

# %%
#artificial neural network
#feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

#initialize artificial neural network
import tensorflow as tf
ann = tf.keras.models.Sequential()

#adding input layer and first hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
#adding second hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

#adding output layer
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

#compiling the ANN
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#training ANN on training set
ann.fit(X_train_scaled, y_train, batch_size=32, epochs=100)

#predict test set results
y_pred = ann.predict(X_test_scaled)

#change to boolean
y_pred = (y_pred > 0.5)

#check performance of ANN
list_ann = model_performance(y_pred)[1]
list_ann
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7093 - accuracy: 0.4981
# Epoch 2/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6729 - accuracy: 0.5998
# Epoch 3/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6349 - accuracy: 0.7124
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5976 - accuracy: 0.7643
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.8107
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.8283
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4216 - accuracy: 0.8285
# Epoch 8/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3438 - accuracy: 0.8663
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2854 - accuracy: 0.8907
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.8872
# Epoch 11/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2161 - accuracy: 0.9088
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1886 - accuracy: 0.9240
# Epoch 13/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1739 - accuracy: 0.9394
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1594 - accuracy: 0.9406
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9531
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1214 - accuracy: 0.9661
# Epoch 17/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1224 - accuracy: 0.9699
# Epoch 18/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0972 - accuracy: 0.9670
# Epoch 19/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0933 - accuracy: 0.9704
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9767
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9767
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9810
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9763
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9788
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 0.9834
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0575 - accuracy: 0.9871
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 0.9820
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9834
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0488 - accuracy: 0.9815
# Epoch 30/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0581 - accuracy: 0.9806
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0523 - accuracy: 0.9787
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0499 - accuracy: 0.9799
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9742
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9871
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 0.9821
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9795
# Epoch 37/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0501 - accuracy: 0.9796
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9758
# Epoch 39/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0432 - accuracy: 0.9869
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0501 - accuracy: 0.9779
# Epoch 41/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0430 - accuracy: 0.9827
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9848
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 0.9855
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9817
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9846
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9842
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9832
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9763
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9832
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9830
# Epoch 51/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0366 - accuracy: 0.9864
# Epoch 52/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9722
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9851
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9833
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9883
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9783
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0473 - accuracy: 0.9784
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 0.9834
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9822
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9867
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9786
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9753
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9830
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9894
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9813
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 0.9839
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9822
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.9799
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9813
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9848
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9862
# Epoch 72/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9809
# Epoch 73/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9752
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9851
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9734
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9851
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9817
# Epoch 78/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0445 - accuracy: 0.9758
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9823
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9826
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9804
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0313 - accuracy: 0.9850
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 0.9820
# Epoch 84/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9868
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9775
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 0.9837
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0392 - accuracy: 0.9858
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 0.9872
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9814
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9754
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9846
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9856
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9796
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9908
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 0.9819
# Epoch 96/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9844
# Epoch 97/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9866
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9786
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9801
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9875
# [[77 20]
#  [18 85]]
# True Negatives: 77
# True Positives: 85
# False Positives: 20
# False Negatives: 18
# Accurary: 0.81
# Precision: 0.81
# Recall: 0.825
# F1 Score: 0.817
# [77, 85, 20, 18, 0.81, 0.81, 0.825, 0.817]

# %%
df = pd.DataFrame(zip(list_nb, list_rf, list_svm, list_kern, list_tree, list_knn, list_log, list_ann), index = ['True Neg', 'True Pos', 'False Pos',
                                    'False Neg', 'Accuracy', 'Precision',
                                    'Recall', 'F1 Score'], columns = ['Naive Bayes', 'Random Forest', 'Linear SVM', 
                                                                      'Kernel SVM', 'Decision Tree', 'K-NN', 'Log Reg.', 'ANN'])
df
# Out:
#            Naive Bayes  Random Forest  Linear SVM  ...    K-NN  Log Reg.     ANN
# True Neg        55.000         87.000      79.000  ...  79.000    80.000  77.000
# True Pos        91.000         58.000      79.000  ...  51.000    75.000  85.000
# False Pos       42.000         10.000      18.000  ...  18.000    17.000  20.000
# False Neg       12.000         45.000      24.000  ...  52.000    28.000  18.000
# Accuracy         0.730          0.725       0.790  ...   0.650     0.775   0.810
# Precision        0.684          0.853       0.814  ...   0.739     0.815   0.810
# Recall           0.883          0.563       0.767  ...   0.495     0.728   0.825
# F1 Score         0.771          0.678       0.790  ...   0.593     0.769   0.817
#
# [8 rows x 8 columns]

# %%
df.to_csv('model_selection.csv', index=True, header=True)
